# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
model_path = '/kaggle/input/googlenewsvectorsnegative300/GoogleNews-vectors-negative300.bin'

# %%
model = KeyedVectors.load_word2vec_format(model_path,binary=True)

# %%
model['man']
# Out:
# array([ 0.32617188,  0.13085938,  0.03466797, -0.08300781,  0.08984375,
#        -0.04125977, -0.19824219,  0.00689697,  0.14355469,  0.0019455 ,
#         0.02880859, -0.25      , -0.08398438, -0.15136719, -0.10205078,
#         0.04077148, -0.09765625,  0.05932617,  0.02978516, -0.10058594,
#        -0.13085938,  0.001297  ,  0.02612305, -0.27148438,  0.06396484,
#        -0.19140625, -0.078125  ,  0.25976562,  0.375     , -0.04541016,
#         0.16210938,  0.13671875, -0.06396484, -0.02062988, -0.09667969,
#         0.25390625,  0.24804688, -0.12695312,  0.07177734,  0.3203125 ,
#         0.03149414, -0.03857422,  0.21191406, -0.00811768,  0.22265625,
#        -0.13476562, -0.07617188,  0.01049805, -0.05175781,  0.03808594,
#        -0.13378906,  0.125     ,  0.0559082 , -0.18261719,  0.08154297,
#        -0.08447266, -0.07763672, -0.04345703,  0.08105469, -0.01092529,
#         0.17480469,  0.30664062, -0.04321289, -0.01416016,  0.09082031,
# ...

# %%
model['man'].shape
# Out:
# (300,)

# %%
model['love'].shape
# Out:
# (300,)

# %%
model.most_similar('man')
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824871301651001),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('suspected_purse_snatcher', 0.571636438369751),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116)]

# %%
model.most_similar('love')
# Out:
# [('loved', 0.6907791495323181),
#  ('adore', 0.6816873550415039),
#  ('loves', 0.661863386631012),
#  ('passion', 0.6100708842277527),
#  ('hate', 0.600395679473877),
#  ('loving', 0.5886635780334473),
#  ('Ilove', 0.5702950954437256),
#  ('affection', 0.5664337873458862),
#  ('undying_love', 0.5547304749488831),
#  ('absolutely_adore', 0.5536840558052063)]

# %%
model.most_similar('cricket')
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
model.most_similar('facebook')
# Out:
# [('Facebook', 0.7563533186912537),
#  ('FaceBook', 0.7076998949050903),
#  ('twitter', 0.6988552212715149),
#  ('myspace', 0.6941817998886108),
#  ('Twitter', 0.664244532585144),
#  ('twitter_facebook', 0.6572229862213135),
#  ('Facebook.com', 0.6529868245124817),
#  ('myspace_facebook', 0.6370643973350525),
#  ('facebook_twitter', 0.6367618441581726),
#  ('linkedin', 0.6356592774391174)]

# %%
model.n_similarity('man', 'women')
# Out:
# 0.84268725

# %%
model.n_similarity('man', 'love')
# Out:
# 0.5697259

# %%
model.n_similarity('man', 'PHP')
# Out:
# 0.23662642

# %%
model.doesnt_match(['php', 'java', 'monkey'])
# Out:
# 'monkey'

# %%
vec = model['tk'] - model['Bangladesh'] + model['England']
model.most_similar(vec)
# Out:
# [('tk', 0.5412393808364868),
#  ('briggs', 0.40561941266059875),
#  ('jonny', 0.4044535756111145),
#  ('hargreaves', 0.4032957851886749),
#  ('delantero', 0.40151628851890564),
#  ('kop', 0.3942388594150543),
#  ('Angleterre', 0.3926285207271576),
#  ('lish', 0.3920195698738098),
#  ('chester', 0.38781633973121643),
#  ('ma_sc', 0.38451245427131653)]
